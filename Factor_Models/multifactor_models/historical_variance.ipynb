# %% [markdown]
# # Historical Variance
#
# Let's see how we'd be calculating a covariance matrix of assets without the help of a factor model

# %%
import numpy as np
import pandas as pd
import time
import os
# import quiz_helper
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (14, 8)

# %% [markdown]
# ### data bundle

# %%
import os
# import quiz_helper
from zipline.data import bundles

# %%
import zipline.data.bundles as bundles
import pandas as pd
from zipline.data.bundles import register, yahoo_NYSE, csvdir

# Specify the bundle name
bundle_name = 'yahoo_NYSE'

start_session = pd.Timestamp('2013-07-01')  # Timezone-naive
end_session = pd.Timestamp('2017-06-30')    # Timezone-naive


register(
    'yahoo_NYSE',
    yahoo_NYSE.yahoo_NYSE(
        tframes=["daily"],
        csvdir="/home/ankit/AI_for_trading/Data/data/eod-quotemedia/"
    )
)

bundle_data = bundles.load('yahoo_NYSE')
# Out:
# /tmp/ipykernel_8946/1568509080.py:12: UserWarning: Overwriting bundle with name 'yahoo_NYSE'
#   register(

# %% [markdown]
# ### Build pipeline engine

# %%
from zipline.pipeline import Pipeline
from zipline.pipeline.factors import AverageDollarVolume
from zipline.utils.calendar_utils import get_calendar
from zipline.pipeline import engine
from zipline.pipeline.loaders import USEquityPricingLoader
from zipline.pipeline.data import USEquityPricing

def choose_price_loader(column):
    if column not in USEquityPricing.columns:
        print("Column not in USEquityPricing.columns")
    return pricing_loader

universe = AverageDollarVolume(window_length=120).top(500) 
trading_calendar = get_calendar('NYSE') 

# Set the dataloader
pricing_loader = USEquityPricingLoader(bundle_data.equity_daily_bar_reader, bundle_data.adjustment_reader,fx_reader=None)


engine = engine.SimplePipelineEngine(choose_price_loader,asset_finder=bundle_data.asset_finder)

# %% [markdown]
# ### View Data¶
# With the pipeline engine built, let's get the stocks at the end of the period in the universe we're using. We'll use these tickers to generate the returns data for the our risk model.

# %%
from zipline.pipeline.domain import US_EQUITIES

universe_end_date = pd.Timestamp('2017-01-06')

universe_tickers = engine\
    .run_pipeline(
        Pipeline(screen=universe,domain=US_EQUITIES),
        universe_end_date,
        universe_end_date)\
    .index.get_level_values(1)\
    .values.tolist()
    
universe_tickers
# Out:
# [Equity(0 [A]),
#  Equity(1 [AAL]),
#  Equity(2 [AAP]),
#  Equity(3 [AAPL]),
#  Equity(4 [ABBV]),
#  Equity(5 [ABT]),
#  Equity(6 [ACN]),
#  Equity(7 [ADBE]),
#  Equity(8 [ADI]),
#  Equity(9 [ADM]),
#  Equity(10 [ADP]),
#  Equity(11 [ADSK]),
#  Equity(12 [AEE]),
#  Equity(13 [AEP]),
#  Equity(14 [AES]),
#  Equity(15 [AET]),
#  Equity(16 [AFL]),
#  Equity(17 [AIG]),
#  Equity(18 [AIV]),
#  Equity(19 [AIZ]),
#  Equity(20 [AJG]),
#  Equity(21 [AKAM]),
#  Equity(22 [ALB]),
#  Equity(23 [ALGN]),
#  Equity(24 [ALK]),
#  Equity(25 [ALL]),
#  Equity(26 [AMAT]),
#  Equity(27 [AMD]),
#  Equity(28 [AME]),
#  Equity(29 [AMG]),
#  Equity(30 [AMGN]),
#  Equity(31 [AMP]),
#  Equity(32 [AMT]),
#  Equity(33 [AMZN]),
#  Equity(34 [ANDV]),
#  Equity(35 [ANSS]),
#  Equity(36 [AON]),
#  Equity(37 [AOS]),
#  Equity(38 [APA]),
#  Equity(39 [APD]),
#  Equity(40 [APH]),
#  Equity(41 [ARE]),
#  Equity(42 [AVB]),
#  Equity(43 [AVGO]),
#  Equity(44 [AVY]),
#  Equity(45 [AWK]),
#  Equity(46 [AXP]),
#  Equity(47 [AYI]),
#  Equity(48 [AZO]),
#  Equity(49 [BA]),
#  Equity(50 [BAC]),
#  Equity(51 [BAX]),
#  Equity(52 [BBY]),
#  Equity(53 [BDX]),
#  Equity(54 [BEN]),
#  Equity(55 [BIIB]),
#  Equity(56 [BK]),
#  Equity(57 [BLK]),
#  Equity(58 [BMY]),
#  Equity(59 [BSX]),
#  Equity(60 [BWA]),
#  Equity(61 [BXP]),
#  Equity(62 [C]),
#  Equity(63 [CAG]),
#  Equity(64 [CAH]),
#  Equity(65 [CAT]),
#  Equity(66 [CB]),
#  Equity(67 [CBOE]),
#  Equity(68 [CCI]),
#  Equity(69 [CCL]),
#  Equity(70 [CF]),
#  Equity(71 [CHD]),
#  Equity(72 [CHRW]),
#  Equity(73 [CHTR]),
#  Equity(74 [CI]),
#  Equity(75 [CINF]),
#  Equity(76 [CL]),
#  Equity(77 [CLX]),
#  Equity(78 [CMA]),
#  Equity(79 [CMCSA]),
#  Equity(80 [CME]),
#  Equity(81 [CMG]),
#  Equity(82 [CMI]),
#  Equity(83 [CMS]),
#  Equity(84 [CNC]),
#  Equity(85 [CNP]),
#  Equity(86 [COF]),
#  Equity(87 [COO]),
#  Equity(88 [COP]),
#  Equity(89 [COST]),
#  Equity(90 [COTY]),
#  Equity(91 [CPB]),
#  Equity(92 [CRM]),
#  Equity(93 [CSCO]),
#  Equity(94 [CSX]),
#  Equity(95 [CTAS]),
#  Equity(96 [CTSH]),
#  Equity(97 [CVS]),
#  Equity(98 [CVX]),
#  Equity(99 [D]),
#  Equity(100 [DAL]),
#  Equity(101 [DE]),
#  Equity(102 [DFS]),
#  Equity(103 [DG]),
#  Equity(104 [DGX]),
#  Equity(105 [DHI]),
#  Equity(106 [DHR]),
#  Equity(107 [DIS]),
#  Equity(108 [DLR]),
#  Equity(109 [DLTR]),
#  Equity(110 [DOV]),
#  Equity(111 [DRI]),
#  Equity(112 [DTE]),
#  Equity(113 [DUK]),
#  Equity(114 [DVA]),
#  Equity(115 [DVN]),
#  Equity(116 [DXC]),
#  Equity(117 [EA]),
#  Equity(118 [EBAY]),
#  Equity(119 [ECL]),
#  Equity(120 [ED]),
#  Equity(121 [EFX]),
#  Equity(122 [EIX]),
#  Equity(123 [EL]),
#  Equity(124 [EMN]),
#  Equity(125 [EMR]),
#  Equity(126 [EOG]),
#  Equity(127 [EQIX]),
#  Equity(128 [EQR]),
#  Equity(129 [EQT]),
#  Equity(130 [ES]),
#  Equity(131 [ESRX]),
#  Equity(132 [ESS]),
#  Equity(133 [ETN]),
#  Equity(134 [ETR]),
#  Equity(135 [EW]),
#  Equity(136 [EXC]),
#  Equity(137 [EXPD]),
#  Equity(138 [EXPE]),
#  Equity(139 [EXR]),
#  Equity(140 [F]),
#  Equity(141 [FAST]),
#  Equity(142 [FCX]),
#  Equity(143 [FDX]),
#  Equity(144 [FE]),
#  Equity(145 [FFIV]),
#  Equity(146 [FIS]),
#  Equity(147 [FITB]),
#  Equity(148 [FL]),
#  Equity(149 [FLR]),
#  Equity(150 [FLS]),
#  Equity(151 [FMC]),
#  Equity(152 [FRT]),
#  Equity(153 [FTI]),
#  Equity(154 [GD]),
#  Equity(155 [GE]),
#  Equity(156 [GILD]),
#  Equity(157 [GIS]),
#  Equity(158 [GLW]),
#  Equity(159 [GM]),
#  Equity(160 [GOOG]),
#  Equity(161 [GOOGL]),
#  Equity(162 [GPC]),
#  Equity(163 [GPN]),
#  Equity(164 [GPS]),
#  Equity(165 [GRMN]),
#  Equity(166 [GS]),
#  Equity(167 [GT]),
#  Equity(168 [GWW]),
#  Equity(169 [HAL]),
#  Equity(170 [HAS]),
#  Equity(171 [HBAN]),
#  Equity(172 [HBI]),
#  Equity(173 [HCA]),
#  Equity(174 [HD]),
#  Equity(175 [HES]),
#  Equity(176 [HIG]),
#  Equity(177 [HOG]),
#  Equity(178 [HOLX]),
#  Equity(179 [HON]),
#  Equity(180 [HP]),
#  Equity(181 [HPQ]),
#  Equity(182 [HRB]),
#  Equity(183 [HRL]),
#  Equity(184 [HSIC]),
#  Equity(185 [HST]),
#  Equity(186 [HSY]),
#  Equity(187 [HUM]),
#  Equity(188 [IBM]),
#  Equity(189 [ICE]),
#  Equity(190 [IDXX]),
#  Equity(191 [IFF]),
#  Equity(192 [ILMN]),
#  Equity(193 [INCY]),
#  Equity(194 [INTC]),
#  Equity(195 [INTU]),
#  Equity(196 [IP]),
#  Equity(197 [IPG]),
#  Equity(198 [IRM]),
#  Equity(199 [ISRG]),
#  Equity(200 [IT]),
#  Equity(201 [ITW]),
#  Equity(202 [IVZ]),
#  Equity(203 [JBHT]),
#  Equity(204 [JCI]),
#  Equity(205 [JNJ]),
#  Equity(206 [JNPR]),
#  Equity(207 [JPM]),
#  Equity(208 [JWN]),
#  Equity(209 [K]),
#  Equity(210 [KEY]),
#  Equity(211 [KIM]),
#  Equity(212 [KLAC]),
#  Equity(213 [KMB]),
#  Equity(214 [KMI]),
#  Equity(215 [KMX]),
#  Equity(216 [KO]),
#  Equity(217 [KR]),
#  Equity(218 [KSS]),
#  Equity(219 [L]),
#  Equity(220 [LEG]),
#  Equity(221 [LEN]),
#  Equity(222 [LH]),
#  Equity(223 [LKQ]),
#  Equity(224 [LLY]),
#  Equity(225 [LMT]),
#  Equity(226 [LNC]),
#  Equity(227 [LNT]),
#  Equity(228 [LOW]),
#  Equity(229 [LRCX]),
#  Equity(230 [LUV]),
#  Equity(231 [LYB]),
#  Equity(232 [M]),
#  Equity(233 [MA]),
#  Equity(234 [MAA]),
#  Equity(235 [MAC]),
#  Equity(236 [MAR]),
#  Equity(237 [MAS]),
#  Equity(238 [MAT]),
#  Equity(239 [MCD]),
#  Equity(240 [MCHP]),
#  Equity(241 [MCK]),
#  Equity(242 [MCO]),
#  Equity(243 [MDLZ]),
#  Equity(244 [MDT]),
#  Equity(245 [MET]),
#  Equity(246 [MGM]),
#  Equity(247 [MHK]),
#  Equity(248 [MKC]),
#  Equity(249 [MLM]),
#  Equity(250 [MMC]),
#  Equity(251 [MNST]),
#  Equity(252 [MO]),
#  Equity(253 [MOS]),
#  Equity(254 [MPC]),
#  Equity(255 [MRK]),
#  Equity(256 [MRO]),
#  Equity(257 [MS]),
#  Equity(258 [MSFT]),
#  Equity(259 [MSI]),
#  Equity(260 [MTB]),
#  Equity(261 [MTD]),
#  Equity(262 [MU]),
#  Equity(263 [NDAQ]),
#  Equity(264 [NEE]),
#  Equity(265 [NEM]),
#  Equity(266 [NFLX]),
#  Equity(267 [NI]),
#  Equity(268 [NKE]),
#  Equity(269 [NOC]),
#  Equity(270 [NOV]),
#  Equity(271 [NRG]),
#  Equity(272 [NSC]),
#  Equity(273 [NTAP]),
#  Equity(274 [NTRS]),
#  Equity(275 [NUE]),
#  Equity(276 [NVDA]),
#  Equity(277 [NWL]),
#  Equity(278 [NWS]),
#  Equity(279 [NWSA]),
#  Equity(280 [O]),
#  Equity(281 [OKE]),
#  Equity(282 [OMC]),
#  Equity(283 [ORCL]),
#  Equity(284 [ORLY]),
#  Equity(285 [OXY]),
#  Equity(286 [PAYX]),
#  Equity(287 [PCAR]),
#  Equity(288 [PCG]),
#  Equity(289 [PDCO]),
#  Equity(290 [PEG]),
#  Equity(291 [PEP]),
#  Equity(292 [PFE]),
#  Equity(293 [PFG]),
#  Equity(294 [PG]),
#  Equity(295 [PGR]),
#  Equity(296 [PH]),
#  Equity(297 [PHM]),
#  Equity(298 [PKG]),
#  Equity(299 [PLD]),
#  Equity(300 [PM]),
#  Equity(301 [PNC]),
#  Equity(302 [PNR]),
#  Equity(303 [PNW]),
#  Equity(304 [PPG]),
#  Equity(305 [PPL]),
#  Equity(306 [PRGO]),
#  Equity(307 [PRU]),
#  Equity(308 [PSA]),
#  Equity(309 [PSX]),
#  Equity(310 [PVH]),
#  Equity(311 [PWR]),
#  Equity(312 [QCOM]),
#  Equity(313 [RCL]),
#  Equity(314 [REG]),
#  Equity(315 [REGN]),
#  Equity(316 [RF]),
#  Equity(317 [RHI]),
#  Equity(318 [RJF]),
#  Equity(319 [RL]),
#  Equity(320 [RMD]),
#  Equity(321 [ROK]),
#  Equity(322 [ROP]),
#  Equity(323 [ROST]),
#  Equity(324 [RRC]),
#  Equity(325 [RSG]),
#  Equity(326 [SBAC]),
#  Equity(327 [SBUX]),
#  Equity(328 [SCHW]),
#  Equity(329 [SEE]),
#  Equity(330 [SHW]),
#  Equity(331 [SIG]),
#  Equity(332 [SJM]),
#  Equity(333 [SLB]),
#  Equity(334 [SLG]),
#  Equity(335 [SNA]),
#  Equity(336 [SNI]),
#  Equity(337 [SNPS]),
#  Equity(338 [SO]),
#  Equity(339 [SPG]),
#  Equity(340 [SPGI]),
#  Equity(341 [SRCL]),
#  Equity(342 [SRE]),
#  Equity(343 [STT]),
#  Equity(344 [STX]),
#  Equity(345 [STZ]),
#  Equity(346 [SWK]),
#  Equity(347 [SWKS]),
#  Equity(348 [SYK]),
#  Equity(349 [SYY]),
#  Equity(350 [T]),
#  Equity(351 [TAP]),
#  Equity(352 [TDG]),
#  Equity(353 [TEL]),
#  Equity(354 [TGT]),
#  Equity(355 [TJX]),
#  Equity(356 [TMO]),
#  Equity(357 [TRIP]),
#  Equity(358 [TROW]),
#  Equity(359 [TRV]),
#  Equity(360 [TSCO]),
#  Equity(361 [TSN]),
#  Equity(362 [TWX]),
#  Equity(363 [TXN]),
#  Equity(364 [TXT]),
#  Equity(365 [UAA]),
#  Equity(366 [UAL]),
#  Equity(367 [UDR]),
#  Equity(368 [UHS]),
#  Equity(369 [ULTA]),
#  Equity(370 [UNH]),
#  Equity(371 [UNM]),
#  Equity(372 [UNP]),
#  Equity(373 [UPS]),
#  Equity(374 [URI]),
#  Equity(375 [USB]),
#  Equity(376 [V]),
#  Equity(377 [VFC]),
#  Equity(378 [VLO]),
#  Equity(379 [VMC]),
#  Equity(380 [VNO]),
#  Equity(381 [VRSK]),
#  Equity(382 [VRSN]),
#  Equity(383 [VRTX]),
#  Equity(384 [VTR]),
#  Equity(385 [VZ]),
#  Equity(386 [WAT]),
#  Equity(387 [WBA]),
#  Equity(388 [WDC]),
#  Equity(389 [WEC]),
#  Equity(390 [WFC]),
#  Equity(391 [WHR]),
#  Equity(392 [WM]),
#  Equity(393 [WMB]),
#  Equity(394 [WMT]),
#  Equity(395 [WRK]),
#  Equity(396 [WU]),
#  Equity(397 [WY]),
#  Equity(398 [WYNN]),
#  Equity(399 [XEL]),
#  Equity(400 [XOM]),
#  Equity(401 [XRAY]),
#  Equity(402 [XRX]),
#  Equity(403 [XYL]),
#  Equity(404 [YUM]),
#  Equity(405 [ZBH]),
#  Equity(406 [ZION]),
#  Equity(407 [ZTS])]

# %%
len(universe_tickers)
# Out:
# 408

# %% [markdown]
# Data portel is interface to all the data used by zipline

# %%
from zipline.data.data_portal import DataPortal

data_portal = DataPortal(
    bundle_data.asset_finder,
    trading_calendar=trading_calendar,
    first_trading_day=bundle_data.equity_daily_bar_reader.first_trading_day,
    equity_minute_reader=None,
    equity_daily_reader=bundle_data.equity_daily_bar_reader,
    adjustment_reader=bundle_data.adjustment_reader)

# %% [markdown]
# ## Get pricing data helper function

# %%
from quiz_helper import get_pricing

# %% [markdown]
# ## get pricing data into a dataframe

# %%
def get_pricing(data_portal, trading_calendar, assets, start_date, end_date, field='close'):
    end_dt = pd.Timestamp(end_date.strftime('%Y-%m-%d'))
    start_dt = pd.Timestamp(start_date.strftime('%Y-%m-%d'))

    end_loc = trading_calendar.closes.index.get_loc(end_dt)
    start_loc = trading_calendar.closes.index.get_loc(start_dt)

    return data_portal.get_history_window(
        assets=assets,
        end_dt=end_dt,
        bar_count=end_loc - start_loc,
        frequency='1d',
        field=field,
        data_frequency='daily')

returns_df = \
    get_pricing(
        data_portal,
        trading_calendar,
        universe_tickers,
        universe_end_date - pd.DateOffset(years=2),
        universe_end_date)\
    .pct_change()[1:].fillna(0) #convert prices into returns

returns_df
# Out:
#             Equity(0 [A])  Equity(1 [AAL])  Equity(2 [AAP])  Equity(3 [AAPL])  \
# 2015-01-08       0.029975         0.012262         0.008765          0.038384
# 2015-01-09      -0.007337        -0.030563        -0.005089          0.001108
# 2015-01-12      -0.011826        -0.046905        -0.008546         -0.024676
# 2015-01-13      -0.013962         0.016539        -0.032530          0.008897
# 2015-01-14      -0.012389        -0.019643        -0.019056         -0.003811
# ...                   ...              ...              ...               ...
# 2016-12-30      -0.001753        -0.011852        -0.006812         -0.007813
# 2017-01-03       0.020413        -0.008353         0.008751          0.002867
# 2017-01-04       0.013121         0.008639         0.008206         -0.001136
# 2017-01-05      -0.011890        -0.017345        -0.000698          0.005103
# 2017-01-06       0.031156         0.006973        -0.013091          0.011148
#
#             Equity(4 [ABBV])  Equity(5 [ABT])  Equity(6 [ACN])  \
# 2015-01-08          0.010459         0.020554         0.015249
# 2015-01-09         -0.027355        -0.010508        -0.001113
# 2015-01-12         -0.000304         0.008407        -0.003007
# 2015-01-13         -0.036040        -0.021281         0.003575
# 2015-01-14          0.004890        -0.007397        -0.011689
# ...                      ...              ...              ...
# 2016-12-30         -0.001754         0.002610         0.001026
# 2017-01-03         -0.003354         0.016662        -0.005720
# 2017-01-04          0.014100         0.007939         0.002404
# 2017-01-05          0.007584         0.008638        -0.014991
# 2017-01-06          0.000314         0.027204         0.011392
#
#             Equity(7 [ADBE])  Equity(8 [ADI])  Equity(9 [ADM])  ...  \
# 2015-01-08          0.025454         0.017655        -0.014609  ...
# 2015-01-09         -0.014811        -0.000730        -0.008530  ...
# 2015-01-12         -0.010022        -0.010051        -0.012495  ...
# 2015-01-13         -0.007452        -0.011445         0.001452  ...
# 2015-01-14         -0.008500        -0.000747        -0.017191  ...
# ...                      ...              ...              ...  ...
# 2016-12-30         -0.007041        -0.013047         0.006393  ...
# 2017-01-03          0.005148        -0.001515         0.011829  ...
# 2017-01-04          0.006378        -0.002069        -0.001732  ...
# 2017-01-05          0.016996        -0.014373        -0.007374  ...
# 2017-01-06          0.022566         0.003926        -0.022941  ...
#
#             Equity(398 [WYNN])  Equity(399 [XEL])  Equity(400 [XOM])  \
# 2015-01-08            0.012031           0.011599           0.016645
# 2015-01-09            0.012499          -0.012285          -0.001410
# 2015-01-12           -0.003958          -0.008845          -0.019218
# 2015-01-13            0.009093           0.008087          -0.003653
# 2015-01-14           -0.008077           0.008852          -0.002889
# ...                        ...                ...                ...
# 2016-12-30           -0.007571          -0.005862          -0.000996
# 2017-01-03            0.010981          -0.001966           0.006980
# 2017-01-04            0.032243           0.004431          -0.011002
# 2017-01-05            0.012849           0.000000          -0.014907
# 2017-01-06            0.010827           0.002941          -0.000565
#
#             Equity(401 [XRAY])  Equity(402 [XRX])  Equity(403 [XYL])  \
# 2015-01-08            0.024689           0.027531           0.007546
# 2015-01-09           -0.014569          -0.005798          -0.018863
# 2015-01-12           -0.009477          -0.010199          -0.021770
# 2015-01-13           -0.003062           0.005166           0.002312
# 2015-01-14           -0.014587           0.004389          -0.006344
# ...                        ...                ...                ...
# 2016-12-30           -0.008927           0.001132          -0.005023
# 2017-01-03            0.015417           0.198053           0.002625
# 2017-01-04            0.008188           0.037736           0.014904
# 2017-01-05           -0.013029          -0.004196          -0.009129
# 2017-01-06           -0.000686          -0.015449          -0.007010
#
#             Equity(404 [YUM])  Equity(405 [ZBH])  Equity(406 [ZION])  \
# 2015-01-08           0.017404           0.010623            0.013994
# 2015-01-09          -0.001758          -0.014427           -0.027975
# 2015-01-12          -0.007480           0.002370           -0.015349
# 2015-01-13          -0.004121           0.002191           -0.017147
# 2015-01-14          -0.004138          -0.013219           -0.017050
# ...                       ...                ...                 ...
# 2016-12-30          -0.004715          -0.002896            0.005842
# 2017-01-03          -0.001895           0.001258            0.003253
# 2017-01-04           0.003639           0.009201            0.014358
# 2017-01-05           0.003310           0.006420           -0.016210
# 2017-01-06           0.012097           0.000098            0.006498
#
#             Equity(407 [ZTS])
# 2015-01-08           0.015399
# 2015-01-09           0.001584
# 2015-01-12          -0.018757
# 2015-01-13          -0.014049
# 2015-01-14           0.005139
# ...                       ...
# 2016-12-30          -0.001678
# 2017-01-03           0.001121
# 2017-01-04           0.009703
# 2017-01-05          -0.003327
# 2017-01-06           0.003152
#
# [504 rows x 408 columns]

# %% [markdown]
# ## Quiz 1
#
# Check out the [numpy.cov documentation](https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.cov.html).  Then think about what's wrong with the following use of numpy.cov

# %%
# What's wrong with this?
annualization_factor = 252
covariance_assets_not_correct = annualization_factor*np.cov(returns_df)

# %%
## TODO: Check the shape of the covariance matrix

covariance_assets_not_correct.shape
# Out:
# (504, 504)

# %% [markdown]
# We expected a matrix of 408 by 408 that is the number of stocks in the universe.

# %% [markdown]
# ## Answer 1 here:

# %% [markdown]
# ## Quiz 2
# How can you adjust the input so that we get the desired covariance matrix of assets?

# %%
# TODO: calculate the covariance matrix of assets
annualization_factor = 252
covariance_assets = annualization_factor*np.cov(returns_df.T)

# %%
covariance_assets.shape
# Out:
# (408, 408)

# %% [markdown]
# ## Answer 2:

# %% [markdown]
# ## Visualize the covariance matrix

# %%
import seaborn as sns

# %%
# view a heatmap of the covariance matrix
sns.heatmap(covariance_assets,cmap='Paired');
## If the colors aren't distinctive, please try a couple of these color schemes:
## cmap = 'tab10'
# cmap = 'Accent'

# %% [markdown]
# ## Quiz 3
# Looking at the colormap are covariances more likely to be positive or negative?  Are covariances likely to be above 0.10 or below 0.10?

# %% [markdown]
# ## Answer 3 here:
# The colormap range is mostly positive, from 0 to 0.30+, so covariances are more likely to be positive than negative. In other words, stocks move with the market. Also, the covariances are mostly below 0.10 rather than higher than 0.10.

# %% [markdown]
# ## Fun Quiz!
# Do you know what the [seaborn visualization package](https://seaborn.pydata.org/index.html) was named after?

# %% [markdown]
# ## Fun Answer! here
# or just check the solution notebook!

# %% [markdown]
# ## Solutions
# The [solution notebook is here](historical_variance_solution.ipynb)
